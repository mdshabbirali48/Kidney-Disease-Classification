# %%
import gdown

# %%
url="https://drive.google.com/file/d/1SmGsbUUP26z7xJFbIfvLkjw8gMtP-FaX/view?usp=sharing"

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1SmGsbUUP26z7xJFbIfvLkjw8gMtP-FaX'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "kidney-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1SmGsbUUP26z7xJFbIfvLkjw8gMtP-FaX
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1SmGsbUUP26z7xJFbIfvLkjw8gMtP-FaX&confirm=t&uuid=baac2ccc-b0b9-483c-b156-cd109673656a
# To: /home/shabbir/Kidney-Disease-Classification/research/kidney-CT-Scan-data.zip
# 100%|██████████| 57.7M/57.7M [00:06<00:00, 9.08MB/s]
# 'kidney-CT-Scan-data.zip'
